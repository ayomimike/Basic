# %% [markdown]
# Python Visualization Project
# 1. Salary Distribution Analysis
# 2. Salary Comparison Based on promotion status
# 3. Increment Percentage Evaluation
# 4. Relationship between experience and salary growth

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import streamlit as st
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv(r'C:\Users\MIKE\Desktop\Python Projects\df.csv')

# %% [markdown]
# ##Salary Distribution Analysis

# %%
df
# Out:
#     Unnamed: 0 first_name last_name                  email   join_date  \
# 0            0       Yuki    Tanaka     yuki34@outlook.com  2021-10-09
# 1            1        Wei     Singh          wei@gmail.com  2021-10-09
# 2            2       Olga     Kumar    unknown@no_mail.com  2022-11-02
# 3            3       Sara     Patel       sara78@yahoo.com  2021-06-25
# 4            4       Luis     Kumar         luis@gmail.com  2023-07-22
# 5            5     Fatima    Garcia       fatima@yahoo.com  2020-01-08
# 6            7    Michael     Kumar  michael43@outlook.com  2024-11-05
# 7            8      Priya    Garcia        priya@yahoo.com         NaN
# 8            9        Wei      Chen         wei4@gmail.com  2022-11-09
# 9           10    Michael    Tanaka  michael41@outlook.com  2021-06-27
# 10          11       Olga    Garcia     olga25@outlook.com  2022-04-16
# 11          12     Fatima     Patel   fatima27@outlook.com  2023-03-11
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['salary'], bins=20, kde=True, color = 'blue', edgecolor='black')
plt.title('Salary Distribution', fontsize=16)
plt.xlabel('Salary', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Salary Comparison Based on promotion status

# %%
df
# Out:
#     Unnamed: 0 first_name last_name                  email   join_date  \
# 0            0       Yuki    Tanaka     yuki34@outlook.com  2021-10-09
# 1            1        Wei     Singh          wei@gmail.com  2021-10-09
# 2            2       Olga     Kumar    unknown@no_mail.com  2022-11-02
# 3            3       Sara     Patel       sara78@yahoo.com  2021-06-25
# 4            4       Luis     Kumar         luis@gmail.com  2023-07-22
# 5            5     Fatima    Garcia       fatima@yahoo.com  2020-01-08
# 6            7    Michael     Kumar  michael43@outlook.com  2024-11-05
# 7            8      Priya    Garcia        priya@yahoo.com         NaN
# 8            9        Wei      Chen         wei4@gmail.com  2022-11-09
# 9           10    Michael    Tanaka  michael41@outlook.com  2021-06-27
# 10          11       Olga    Garcia     olga25@outlook.com  2022-04-16
# 11          12     Fatima     Patel   fatima27@outlook.com  2023-03-11
# ...

# %%
employee_melted_data = pd.melt(df,
    id_vars=['promotion_hr_based'], value_vars=['salary', 'final_incremented_salary'], var_name='Salary Type', value_name='Salary')
plt.figure(figsize=(10, 6))
sns.barplot(x='promotion_hr_based', y='Salary', hue='Salary Type', data=employee_melted_data, palette='Set2')
plt.title('Salary Comparison by Promotion Status', fontsize=16) 
plt.xlabel('Promotion HR Data', fontsize=12)
plt.ylabel('Salary', fontsize=12)
plt.legend(title='Salary Type')
plt.show()

# %% [markdown]
# Increment Percentage Evaluation

# %%
df
# Out:
#     Unnamed: 0 first_name last_name                  email   join_date  \
# 0            0       Yuki    Tanaka     yuki34@outlook.com  2021-10-09
# 1            1        Wei     Singh          wei@gmail.com  2021-10-09
# 2            2       Olga     Kumar    unknown@no_mail.com  2022-11-02
# 3            3       Sara     Patel       sara78@yahoo.com  2021-06-25
# 4            4       Luis     Kumar         luis@gmail.com  2023-07-22
# 5            5     Fatima    Garcia       fatima@yahoo.com  2020-01-08
# 6            7    Michael     Kumar  michael43@outlook.com  2024-11-05
# 7            8      Priya    Garcia        priya@yahoo.com         NaN
# 8            9        Wei      Chen         wei4@gmail.com  2022-11-09
# 9           10    Michael    Tanaka  michael41@outlook.com  2021-06-27
# 10          11       Olga    Garcia     olga25@outlook.com  2022-04-16
# 11          12     Fatima     Patel   fatima27@outlook.com  2023-03-11
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='promotion_hr_based', y='increment_percentage', hue='promotion_hr_based', data=df, palette='pastel')
plt.title('Increment Percentage', fontsize=16)
plt.xlabel('Promotion HR Data', fontsize=12)
plt.ylabel('Increment Percentage (%)', fontsize=12)
legend_labels = ['No Promotion', 'Promotion']
plt.legend(title='Promotion Status', labels=legend_labels)
plt.show()
